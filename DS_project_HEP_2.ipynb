# %% [markdown]
# <a href="https://colab.research.google.com/github/DhwaniShah7/Portfolio/blob/main/DS_project_HEP_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <center>${\text{IDC 409 - Introduction to Data Science}}$</center>
# # <center>${\text{Project 02: HEP Event Classification}}$</center>

# %% [markdown]
# # <center>${\text{Group Members:}}$</center>
# #### <center>${\text{Kunal Kashyap (MS20030)}}$</center>
# #### <center>${\text{Aditi (MS20020)}}$</center>
# #### <center>${\text{Dhwani Shah (MS20156)}}$</center>

# %% [markdown]
# ## Loading basic packages and mounting drive

# %%
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Loading the Data

# %%
df = pd.read_csv("/content/drive/MyDrive/data_hep.csv")
# Removing the first column (that is index)
df = df.drop("Unnamed: 0",axis=1)

# %%
# Visualizing the data
df
# Out:
#              R2  thrustBm  thrustOm   cosTBTO    cosTBz  \
# 0      0.152200  0.818042  0.678908  0.925376  0.641596
# 1      0.122531  0.847877  0.661546  0.203175  0.960107
# 2      0.071109  0.823682  0.659284  0.586194  0.667930
# 3      0.123307  0.849041  0.713995  0.343100  0.599684
# 4      0.128661  0.850345  0.700636  0.598284  0.751411
# ...         ...       ...       ...       ...       ...
# 70601  0.341170  0.822778  0.905524  0.744942  0.883310
# 70602  0.431197  0.890331  0.851992  0.979008  0.270003
# 70603  0.345012  0.897968  0.745580  0.974656  0.691979
# 70604  0.240343  0.910267  0.698762  0.960566  0.441567
# 70605  0.309568  0.903780  0.728094  0.984371  0.469564
#
#        KSFWVariables__boet__bc  KSFWVariables__bomm2__bc  CleoConeCS__bo1__bc  \
# 0                     5.492738                  7.326161             0.062815
# 1                     3.548602                  5.346302             0.000000
# 2                     7.739933                 -1.734496             0.393218
# 3                     6.336428                  5.429208             0.000000
# 4                     7.520575                 -1.092915             0.105494
# ...                        ...                       ...                  ...
# 70601                 5.254729                  2.711209             0.229089
# 70602                10.016900                 -1.206864             0.000000
# 70603                 8.154435                 -0.880221             4.716620
# 70604                 9.145159                 -9.401502             2.592608
# 70605                 8.368848                 -1.194669             0.336638
#
#        CleoConeCS__bo2__bc  CleoConeCS__bo3__bc  ...  \
# 0                 0.923991             1.262607  ...
# 1                 2.317477             0.000000  ...
# 2                 0.061572             2.128880  ...
# 3                 0.000000             2.233941  ...
# 4                 0.789670             2.863936  ...
# ...                    ...                  ...  ...
# 70601             0.000000             0.411111  ...
# 70602             4.097687             2.356474  ...
# 70603             1.190169             1.030242  ...
# 70604             0.548217             3.795009  ...
# 70605             5.627395             0.358319  ...
#
#        KSFWVariables__bohoo2__cmFS1__bc  KSFWVariables__bohoo3__cmFS1__bc  \
# 0                             -0.000648                         -0.000956
# 1                             -0.004079                          0.000975
# 2                             -0.002341                         -0.002249
# 3                             -0.001151                         -0.000096
# 4                              0.004459                         -0.001671
# ...                                 ...                               ...
# 70601                          0.007728                         -0.003148
# 70602                          0.063099                         -0.006214
# 70603                          0.026411                          0.000968
# 70604                          0.020226                         -0.006749
# 70605                          0.007418                         -0.002189
#
#        KSFWVariables__bohoo4__cmFS1__bc  foxWolframR1  foxWolframR2  \
# 0                              0.003297      0.315513      0.257067
# 1                             -0.010682      0.699070      0.425364
# 2                             -0.000644      0.351783      0.278459
# 3                              0.003249      0.616451      0.581567
# 4                             -0.000072      0.099653      0.368981
# ...                                 ...           ...           ...
# 70601                          0.013386      0.240637      0.320524
# 70602                          0.009684      0.254839      0.436554
# 70603                          0.004867      0.089218      0.603980
# 70604                          0.021568      0.406443      0.524733
# 70605                          0.006471      0.566576      0.547461
#
#        foxWolframR3  foxWolframR4    thrust  thrustAxisCosTheta  type
# 0          0.165595      0.099685  0.766103            0.584374     1
# 1          0.337010      0.357491  0.842736            0.960207     1
# 2          0.247533      0.171277  0.773620            0.723453     1
# 3          0.504908      0.313320  0.906921            0.631777     1
# 4          0.190910      0.247606  0.824495            0.589225     1
# ...             ...           ...       ...                 ...   ...
# 70601      0.114465      0.172375  0.789952            0.865978     2
# 70602      0.169985      0.252282  0.861856           -0.084869     2
# 70603      0.223313      0.441302  0.903512            0.689248     2
# 70604      0.335748      0.384065  0.868288           -0.230441     2
# 70605      0.335370      0.377713  0.882218            0.547106     2
#
# [70606 rows x 60 columns]

# %%
# Obtaining X nd Y (Labels) from the dataframe.
Y = df["type"].values
X = df.drop("type",axis=1).values
# Hot encoding Y values (1 in ith index if it is a i+1 class event)
Y=np.eye(5)[Y-1]

# %% [markdown]
# # Approach 1:
# \\
# Use a simple sequential neural network (MLP) to classify data without dimension reduction

# %%
# Importing required tenserflow keras packages for MLP construction
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LeakyReLU, BatchNormalization, Dropout

# Splitting the data into training and validation subsets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Standardize the input data (IMPORTANT)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Define the neural network architecture (Using simple MLP)
model = Sequential()
model.add(Dense(625, input_dim= 59))
model.add(LeakyReLU(alpha=0.1))
model.add(BatchNormalization())
model.add(Dense(512))
model.add(LeakyReLU(alpha=0.1))
model.add(BatchNormalization())
model.add(Dense(225))
model.add(LeakyReLU(alpha=0.1))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Dense(20))
model.add(Dense(5, activation='softmax'))


# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Training
history = model.fit(X_train, Y_train, epochs=50, batch_size=500, validation_data=(X_test, Y_test))

# Evaluate the model on the test data
loss, accuracy = model.evaluate(X_test, Y_test)
print(f'Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/50
# 113/113 [==============================] - 10s 9ms/step - loss: 0.9773 - accuracy: 0.6830 - val_loss: 0.8551 - val_accuracy: 0.7059
# Epoch 2/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.7798 - accuracy: 0.7247 - val_loss: 0.7855 - val_accuracy: 0.7174
# Epoch 3/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.7357 - accuracy: 0.7370 - val_loss: 0.7465 - val_accuracy: 0.7262
# Epoch 4/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.7125 - accuracy: 0.7428 - val_loss: 0.7287 - val_accuracy: 0.7363
# Epoch 5/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.7016 - accuracy: 0.7475 - val_loss: 0.7213 - val_accuracy: 0.7332
# Epoch 6/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.6897 - accuracy: 0.7511 - val_loss: 0.7137 - val_accuracy: 0.7425
# Epoch 7/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.6832 - accuracy: 0.7537 - val_loss: 0.7121 - val_accuracy: 0.7417
# Epoch 8/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.6762 - accuracy: 0.7560 - val_loss: 0.7186 - val_accuracy: 0.7344
# Epoch 9/50
# 113/113 [==============================] - 1s 8ms/step - loss: 0.6676 - accuracy: 0.7572 - val_loss: 0.7074 - val_accuracy: 0.7439
# Epoch 10/50
# 113/113 [==============================] - 1s 10ms/step - loss: 0.6569 - accuracy: 0.7623 - val_loss: 0.7100 - val_accuracy: 0.7419
# Epoch 11/50
# 113/113 [==============================] - 1s 10ms/step - loss: 0.6547 - accuracy: 0.7632 - val_loss: 0.7038 - val_accuracy: 0.7476
# Epoch 12/50
# 113/113 [==============================] - 1s 9ms/step - loss: 0.6483 - accuracy: 0.7652 - val_loss: 0.6985 - val_accuracy: 0.7481
# Epoch 13/50
# 113/113 [==============================] - 1s 6ms/step - loss: 0.6408 - accuracy: 0.7668 - val_loss: 0.7052 - val_accuracy: 0.7464
# Epoch 14/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.6337 - accuracy: 0.7701 - val_loss: 0.7097 - val_accuracy: 0.7432
# Epoch 15/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.6261 - accuracy: 0.7718 - val_loss: 0.7095 - val_accuracy: 0.7414
# Epoch 16/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.6198 - accuracy: 0.7754 - val_loss: 0.7056 - val_accuracy: 0.7466
# Epoch 17/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.6127 - accuracy: 0.7763 - val_loss: 0.7104 - val_accuracy: 0.7423
# Epoch 18/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.6043 - accuracy: 0.7798 - val_loss: 0.7042 - val_accuracy: 0.7451
# Epoch 19/50
# 113/113 [==============================] - 1s 9ms/step - loss: 0.5978 - accuracy: 0.7824 - val_loss: 0.7043 - val_accuracy: 0.7469
# Epoch 20/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.5903 - accuracy: 0.7823 - val_loss: 0.7085 - val_accuracy: 0.7481
# Epoch 21/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.5813 - accuracy: 0.7876 - val_loss: 0.7210 - val_accuracy: 0.7367
# Epoch 22/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.5720 - accuracy: 0.7905 - val_loss: 0.7210 - val_accuracy: 0.7432
# Epoch 23/50
# 113/113 [==============================] - 1s 6ms/step - loss: 0.5604 - accuracy: 0.7932 - val_loss: 0.7154 - val_accuracy: 0.7449
# Epoch 24/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.5526 - accuracy: 0.7954 - val_loss: 0.7236 - val_accuracy: 0.7418
# Epoch 25/50
# 113/113 [==============================] - 1s 8ms/step - loss: 0.5483 - accuracy: 0.7973 - val_loss: 0.7179 - val_accuracy: 0.7420
# Epoch 26/50
# 113/113 [==============================] - 1s 10ms/step - loss: 0.5336 - accuracy: 0.8017 - val_loss: 0.7252 - val_accuracy: 0.7419
# Epoch 27/50
# 113/113 [==============================] - 1s 10ms/step - loss: 0.5235 - accuracy: 0.8041 - val_loss: 0.7225 - val_accuracy: 0.7422
# Epoch 28/50
# 113/113 [==============================] - 1s 8ms/step - loss: 0.5126 - accuracy: 0.8073 - val_loss: 0.7269 - val_accuracy: 0.7443
# Epoch 29/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.5043 - accuracy: 0.8112 - val_loss: 0.7356 - val_accuracy: 0.7413
# Epoch 30/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.4897 - accuracy: 0.8154 - val_loss: 0.7411 - val_accuracy: 0.7447
# Epoch 31/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.4791 - accuracy: 0.8187 - val_loss: 0.7429 - val_accuracy: 0.7410
# Epoch 32/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.4673 - accuracy: 0.8233 - val_loss: 0.7446 - val_accuracy: 0.7447
# Epoch 33/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.4561 - accuracy: 0.8262 - val_loss: 0.7406 - val_accuracy: 0.7421
# Epoch 34/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.4463 - accuracy: 0.8294 - val_loss: 0.7576 - val_accuracy: 0.7391
# Epoch 35/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.4334 - accuracy: 0.8344 - val_loss: 0.7946 - val_accuracy: 0.7277
# Epoch 36/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.4239 - accuracy: 0.8372 - val_loss: 0.7830 - val_accuracy: 0.7378
# Epoch 37/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.4157 - accuracy: 0.8407 - val_loss: 0.7753 - val_accuracy: 0.7437
# Epoch 38/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.3976 - accuracy: 0.8462 - val_loss: 0.7928 - val_accuracy: 0.7401
# Epoch 39/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.3874 - accuracy: 0.8503 - val_loss: 0.8031 - val_accuracy: 0.7336
# Epoch 40/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.3805 - accuracy: 0.8518 - val_loss: 0.8168 - val_accuracy: 0.7407
# Epoch 41/50
# 113/113 [==============================] - 1s 9ms/step - loss: 0.3701 - accuracy: 0.8589 - val_loss: 0.8272 - val_accuracy: 0.7401
# Epoch 42/50
# 113/113 [==============================] - 1s 10ms/step - loss: 0.3631 - accuracy: 0.8603 - val_loss: 0.8190 - val_accuracy: 0.7413
# Epoch 43/50
# 113/113 [==============================] - 1s 10ms/step - loss: 0.3568 - accuracy: 0.8629 - val_loss: 0.8203 - val_accuracy: 0.7413
# Epoch 44/50
# 113/113 [==============================] - 1s 8ms/step - loss: 0.3405 - accuracy: 0.8679 - val_loss: 0.8418 - val_accuracy: 0.7347
# Epoch 45/50
# 113/113 [==============================] - 1s 6ms/step - loss: 0.3316 - accuracy: 0.8720 - val_loss: 0.8668 - val_accuracy: 0.7339
# Epoch 46/50
# 113/113 [==============================] - 1s 6ms/step - loss: 0.3261 - accuracy: 0.8728 - val_loss: 0.8434 - val_accuracy: 0.7269
# Epoch 47/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.3089 - accuracy: 0.8811 - val_loss: 0.9045 - val_accuracy: 0.7350
# Epoch 48/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.3091 - accuracy: 0.8810 - val_loss: 0.8884 - val_accuracy: 0.7381
# Epoch 49/50
# 113/113 [==============================] - 1s 7ms/step - loss: 0.2966 - accuracy: 0.8857 - val_loss: 0.8711 - val_accuracy: 0.7318
# Epoch 50/50
# 113/113 [==============================] - 1s 6ms/step - loss: 0.2855 - accuracy: 0.8877 - val_loss: 0.9284 - val_accuracy: 0.7286
# 442/442 [==============================] - 1s 3ms/step - loss: 0.9284 - accuracy: 0.7286
# Test Loss: 0.9284, Test Accuracy: 0.7286

# %% [markdown]
# <b>We could obtain an accuracy ~ 75% using this method</b>

# %% [markdown]
# # Approach 2:
# \\
# Use PCA to reduce dimentionality and then use a simple sequential neural network (MLP) to classify data

# %%
# Required packages
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LeakyReLU, BatchNormalization, Dropout, ReLU
from sklearn.decomposition import PCA # PAckage for PCA



# Standardizing the input data
scaler = StandardScaler()
X_T = scaler.fit_transform(X)


#PCA to reduce dimentionality
pca = PCA(n_components = 20)  #Keeping number of components = 20
pca.fit(X_T)
X_P = pca.fit_transform(X_T)



# Obtaibing train and Test subsets
X_train, X_test, Y_train, Y_test = train_test_split(X_P, Y, test_size=0.2, random_state=42)




# Define the neural network architecture
model = Sequential()
model.add(Dense(625, input_dim= 20))
model.add(LeakyReLU(alpha=0.1))
model.add(BatchNormalization())
model.add(Dense(512))
model.add(LeakyReLU(alpha=0.1))
model.add(BatchNormalization())
model.add(Dense(225))
model.add(LeakyReLU(alpha=0.1))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Dense(20))
model.add(Dense(5, activation='softmax'))


# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, Y_train, epochs=20, batch_size=500, validation_data=(X_test, Y_test))

# Evaluate the model on the test data
loss, accuracy = model.evaluate(X_test, Y_test)
print(f'Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/20
# 113/113 [==============================] - 3s 9ms/step - loss: 1.0379 - accuracy: 0.6689 - val_loss: 0.9114 - val_accuracy: 0.7012
# Epoch 2/20
# 113/113 [==============================] - 1s 7ms/step - loss: 0.8398 - accuracy: 0.7024 - val_loss: 0.8422 - val_accuracy: 0.7095
# Epoch 3/20
# 113/113 [==============================] - 1s 7ms/step - loss: 0.8005 - accuracy: 0.7095 - val_loss: 0.8054 - val_accuracy: 0.7123
# Epoch 4/20
# 113/113 [==============================] - 1s 7ms/step - loss: 0.7825 - accuracy: 0.7150 - val_loss: 0.7874 - val_accuracy: 0.7109
# Epoch 5/20
# 113/113 [==============================] - 1s 9ms/step - loss: 0.7715 - accuracy: 0.7182 - val_loss: 0.7854 - val_accuracy: 0.7153
# Epoch 6/20
# 113/113 [==============================] - 1s 10ms/step - loss: 0.7639 - accuracy: 0.7200 - val_loss: 0.7741 - val_accuracy: 0.7189
# Epoch 7/20
# 113/113 [==============================] - 1s 11ms/step - loss: 0.7600 - accuracy: 0.7211 - val_loss: 0.7738 - val_accuracy: 0.7174
# Epoch 8/20
# 113/113 [==============================] - 1s 12ms/step - loss: 0.7533 - accuracy: 0.7245 - val_loss: 0.7672 - val_accuracy: 0.7238
# Epoch 9/20
# 113/113 [==============================] - 1s 7ms/step - loss: 0.7488 - accuracy: 0.7250 - val_loss: 0.7831 - val_accuracy: 0.7172
# Epoch 10/20
# 113/113 [==============================] - 1s 7ms/step - loss: 0.7450 - accuracy: 0.7265 - val_loss: 0.7741 - val_accuracy: 0.7209
# Epoch 11/20
# 113/113 [==============================] - 1s 7ms/step - loss: 0.7383 - accuracy: 0.7289 - val_loss: 0.7727 - val_accuracy: 0.7196
# Epoch 12/20
# 113/113 [==============================] - 1s 7ms/step - loss: 0.7368 - accuracy: 0.7281 - val_loss: 0.7743 - val_accuracy: 0.7209
# Epoch 13/20
# 113/113 [==============================] - 1s 7ms/step - loss: 0.7318 - accuracy: 0.7318 - val_loss: 0.7788 - val_accuracy: 0.7155
# Epoch 14/20
# 113/113 [==============================] - 1s 7ms/step - loss: 0.7261 - accuracy: 0.7324 - val_loss: 0.7748 - val_accuracy: 0.7147
# Epoch 15/20
# 113/113 [==============================] - 1s 7ms/step - loss: 0.7237 - accuracy: 0.7338 - val_loss: 0.7807 - val_accuracy: 0.7136
# Epoch 16/20
# 113/113 [==============================] - 1s 7ms/step - loss: 0.7198 - accuracy: 0.7340 - val_loss: 0.7762 - val_accuracy: 0.7132
# Epoch 17/20
# 113/113 [==============================] - 1s 7ms/step - loss: 0.7169 - accuracy: 0.7354 - val_loss: 0.7858 - val_accuracy: 0.7078
# Epoch 18/20
# 113/113 [==============================] - 1s 7ms/step - loss: 0.7128 - accuracy: 0.7380 - val_loss: 0.7780 - val_accuracy: 0.7155
# Epoch 19/20
# 113/113 [==============================] - 1s 6ms/step - loss: 0.7089 - accuracy: 0.7406 - val_loss: 0.7694 - val_accuracy: 0.7153
# Epoch 20/20
# 113/113 [==============================] - 1s 8ms/step - loss: 0.7019 - accuracy: 0.7406 - val_loss: 0.7864 - val_accuracy: 0.7127
# 442/442 [==============================] - 2s 4ms/step - loss: 0.7864 - accuracy: 0.7127
# Test Loss: 0.7864, Test Accuracy: 0.7127

# %% [markdown]
# ## Predicting events

# %% [markdown]
# <b>We could obtain accuracy ~71% with dimensionality reduced to 20. In general, the accuracy decreased slowly as we reduced the number of components</b>

# %%
T = X_test[30:40]
Lab = Y_test[30:40]

pred = model.predict(T)
print("Predicted lables : ",np.argmax(pred,axis=1)+1)
print("Actual    lables : ",np.argmax(Lab,axis=1)+1)
# Out:
# 1/1 [==============================] - 0s 29ms/step
# Predicted lables :  [2 1 1 2 2 2 3 1 1 1]
# Actual    lables :  [2 1 1 3 2 2 5 1 1 1]
